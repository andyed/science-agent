# %% [markdown]
# ## Key Claims (authoritative for paper writers)
#
# | Claim | Value (typed) |
# |---|---|
# | Top-Ad lateral/arc ratio | `Lateral   Fitts ID   Max retreat
#      Organic   450       1.28        53      1.86` |
