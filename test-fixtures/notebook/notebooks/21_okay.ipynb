# %% [markdown]
# ## Key Claims (authoritative for paper writers)
#
# | ID | Claim | Value |
# |---|---|---|
# | **K1** | a parseable fixture claim | 0.5 |
# | **K-bbox-1** | a parallel-namespace fixture claim | 0.6 |
